# %% [markdown]
# # Errores de codificación a nivel de mesa electoral
#
# Busca mesas con resultados sospechosos en municipios con más de 200.000 votos válidos.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import glob
import pandas as pd
from common_functions import get_parties, get_election_results, process_election, find_suspicious, find_suspicious_2

# %% [markdown]
# Estos archivos provienen de http://www.infoelectoral.mir.es/infoelectoral/min/areaDescarga.html. Para acceder a ellos hay que ir al final de la página, hasta la sección *Extracción de datos*, y luego elegir los que nos interesen. Los que empiezan por *02* son elecciones municipales, *04* generales, etc. Dentro de cada .zip hay un archivo DOCX / RTF con instrucciones sobre los distintos códigos.

# %%
datafiles = sorted(glob.glob("/home/chema/Dropbox/data/elecciones/*.zip"))
for x in enumerate(datafiles):
    print(x)
# Out:
# (0, '/home/chema/Dropbox/data/elecciones/02201512_MESA.zip')
# (1, '/home/chema/Dropbox/data/elecciones/02201606_MESA.zip')
# (2, '/home/chema/Dropbox/data/elecciones/04201105_MESA.zip')
# (3, '/home/chema/Dropbox/data/elecciones/04201505_MESA.zip')

# %% [markdown]
# Vamos a buscar municipios que tuvieran más de 200.000 votos válidos.

# %%
file_idx = 2
eldata = process_election(datafiles[file_idx], filter_prov_code = None, filter_town_code = None)
town_totals = eldata.groupby(['prov_code', 'town_code'])\
    .agg({'votes': 'sum'})\
    .sort_values('votes', ascending = False)\
    .reset_index()
town_totals = town_totals.loc[town_totals['votes'] > 100000, :]
print(town_totals.shape)
# Out:
# (20, 3)

# %%
town_names = pd.read_csv("/home/chema/Dropbox/data/elecciones/11codmun.csv", 
                         dtype = {'CPRO': str, 'CMUN': str})
town_names.columns = ['prov_code', 'town_code', 'dc', 'name']
town_totals = pd.merge(town_totals, town_names)
display(town_totals)
# Out:
#    prov_code town_code    votes  dc                         name
# 0         28       079  1480082   6                       Madrid
# 1         08       019   578876   3                    Barcelona
# 2         46       250   388595   8                     Valencia
# 3         41       091   327372   7                      Sevilla
# 4         50       297   306935   3                     Zaragoza
# 5         29       067   225845   2                       Málaga
# 6         30       030   198146   8                       Murcia
# 7         48       020   165285   9                       Bilbao
# 8         47       186   164165   8                   Valladolid
# 9         14       021   158779   4                      Córdoba
# 10        35       016   153204   7  Palmas de Gran Canaria, Las
# 11        33       024   147237   1                        Gijón
# 12        03       014   141436   9             Alicante/Alacant
# 13        36       057   141260   7                         Vigo
# 14        07       040   140785   7                        Palma
# 15        33       044   113962   7                       Oviedo
# 16        18       087   113731   7                      Granada
# 17        15       030   112206   8                    Coruña, A
# 18        03       065   111606   1                    Elche/Elx
# 19        01       059   107586   0              Vitoria-Gasteiz

# %%
for row in town_totals.itertuples():
    prov_code = row.prov_code
    town_code = row.town_code
    print(f"Processing {row.name}...")
    df = eldata.loc[(eldata['prov_code'] == prov_code) & (eldata['town_code'] == town_code), :]
    suspicious_df, total_boxes = find_suspicious(df)
    print(f"{suspicious_df.shape[0]} suspicious ballot boxes out of a total of {total_boxes}")
# Out:
# Processing Madrid...
# 12 suspicious ballot boxes out of a total of 3347
# Processing Barcelona...
# 2 suspicious ballot boxes out of a total of 1232
# Processing Valencia...
# 1 suspicious ballot boxes out of a total of 920
# Processing Sevilla...
# 1 suspicious ballot boxes out of a total of 938
# Processing Zaragoza...
# 0 suspicious ballot boxes out of a total of 971
# Processing Málaga...
# 1 suspicious ballot boxes out of a total of 715
# Processing Murcia...
# 1 suspicious ballot boxes out of a total of 501
# Processing Bilbao...
# 1 suspicious ballot boxes out of a total of 407
# Processing Valladolid...
# 2 suspicious ballot boxes out of a total of 433
# Processing Córdoba...
# 2 suspicious ballot boxes out of a total of 413
# Processing Palmas de Gran Canaria, Las...
# 3 suspicious ballot boxes out of a total of 539
# Processing Gijón...
# 1 suspicious ballot boxes out of a total of 375
# Processing Alicante/Alacant...
# 2 suspicious ballot boxes out of a total of 467
# Processing Vigo...
# 0 suspicious ballot boxes out of a total of 376
# Processing Palma...
# 1 suspicious ballot boxes out of a total of 401
# Processing Oviedo...
# 0 suspicious ballot boxes out of a total of 298
# Processing Granada...
# 0 suspicious ballot boxes out of a total of 348
# Processing Coruña, A...
# 0 suspicious ballot boxes out of a total of 300
# Processing Elche/Elx...
# 0 suspicious ballot boxes out of a total of 348
# Processing Vitoria-Gasteiz...
# 0 suspicious ballot boxes out of a total of 305

# %%
# Second method
for row in town_totals.itertuples():
    prov_code = row.prov_code
    town_code = row.town_code
    print(f"Processing {row.name}...")
    df = eldata.loc[(eldata['prov_code'] == prov_code) & (eldata['town_code'] == town_code), :]
    suspicious_df, total_boxes = find_suspicious_2(df)
    print(f"{suspicious_df.shape[0]} suspicious ballot boxes out of a total of {total_boxes}")
# Out:
# Processing Madrid...
#      dist_code section_code table_code  bad_counts
# 1735        11          022          A           5
# 507         04          053          U           5
# 435         03          097          A           5
# 393         03          070          U           5
# 2869        17          026          U           5
# 3347 suspicious ballot boxes out of a total of 3347
# Processing Barcelona...
#     dist_code section_code table_code  bad_counts
# 336        03          046          U           5
# 133        02          054          A           5
# 583        05          094          B           5
# 119        02          045          U           5
# 415        04          002          B           5
# 1232 suspicious ballot boxes out of a total of 1232
# Processing Valencia...
#     dist_code section_code table_code  bad_counts
# 371        12          042          B           7
# 379        13          005          A           7
# 133        06          004          U           7
# 132        06          001          A           7
# 127        05          039          B           7
# 510 suspicious ballot boxes out of a total of 920
# Processing Sevilla...
#     dist_code section_code table_code  bad_counts
# 931        11          016          A           5
# 860        10          005          B           4
# 826        09          050          B           4
# 828        09          051          B           4
# 551        07          007          B           4
# 938 suspicious ballot boxes out of a total of 938
# Processing Zaragoza...
#     dist_code section_code table_code  bad_counts
# 142        02          053          B           5
# 675        08          024          A           5
# 202        03          037          A           5
# 694        09          009          A           4
# 462        05          020          B           4
# 971 suspicious ballot boxes out of a total of 971
# Processing Málaga...
#     dist_code section_code table_code  bad_counts
# 126        06          007          B           4
# 90         03          001          U           4
# 347        08          006          A           4
# 324        07          087          U           4
# 355        08          011          A           4
# 715 suspicious ballot boxes out of a total of 715
# Processing Murcia...
#     dist_code section_code table_code  bad_counts
# 296        04          069          B           4
# 125        02          047          U           4
# 422        06          033          B           4
# 191        03          041          B           4
# 37         01          033          U           4
# 501 suspicious ballot boxes out of a total of 501
# Processing Bilbao...
#     dist_code section_code table_code  bad_counts
# 203        05          008          B           4
# 151        04          009          A           4
# 74         02          011          A           4
# 77         02          012          B           4
# 78         02          013          U           4
# 407 suspicious ballot boxes out of a total of 407
# Processing Valladolid...
#     dist_code section_code table_code  bad_counts
# 430        12          004          B           3
# 114        06          005          A           3
# 321        10          034          A           3
# 319        10          033          A           3
# 318        10          032          U           3
# 431 suspicious ballot boxes out of a total of 433
# Processing Córdoba...
#     dist_code section_code table_code  bad_counts
# 238        06          027          U           4
# 1          01          002          U           4
# 228        06          021          U           4
# 36         01          023          A           4
# 411        10          046          U           3
# 412 suspicious ballot boxes out of a total of 413
# Processing Palmas de Gran Canaria, Las...
#     dist_code section_code table_code  bad_counts
# 179        02          048          B           5
# 348        04          038          A           5
# 469        05          021          U           5
# 329        04          028          B           4
# 365        04          048          A           4
# 492 suspicious ballot boxes out of a total of 539
# Processing Gijón...
#     dist_code section_code table_code  bad_counts
# 214        07          005          B           5
# 230        07          016          U           5
# 294        07          050          A           5
# 54         03          002          B           5
# 246        07          025          B           5
# 375 suspicious ballot boxes out of a total of 375
# Processing Alicante/Alacant...
#     dist_code section_code table_code  bad_counts
# 52         02          010          A           4
# 262        05          015          A           3
# 288        06          005          B           3
# 370        07          018          A           3
# 372        07          019          A           3
# 439 suspicious ballot boxes out of a total of 467
# Processing Vigo...
#     dist_code section_code table_code  bad_counts
# 0          01          001          U           3
# 116        03          032          U           3
# 118        03          034          A           3
# 287        07          024          A           3
# 285        07          023          A           3
# 375 suspicious ballot boxes out of a total of 376
# Processing Palma...
#     dist_code section_code table_code  bad_counts
# 313        04          060          U           5
# 37         02          012          A           4
# 34         02          010          U           4
# 209        03          049          A           4
# 181        03          031          B           4
# 383 suspicious ballot boxes out of a total of 401
# Processing Oviedo...
#     dist_code section_code table_code  bad_counts
# 77         05          001          B           5
# 161        08          002          B           5
# 91         05          010          A           5
# 287        15          003          U           5
# 149        07          005          U           4
# 298 suspicious ballot boxes out of a total of 298
# Processing Granada...
#     dist_code section_code table_code  bad_counts
# 80         02          027          U           4
# 236        06          011          B           4
# 194        03          036          B           4
# 158        03          020          A           4
# 340        09          005          U           4
# 348 suspicious ballot boxes out of a total of 348
# Processing Coruña, A...
#     dist_code section_code table_code  bad_counts
# 148        05          016          B           4
# 84         04          002          B           4
# 136        05          009          A           4
# 209        07          011          A           4
# 160        06          001          B           4
# 296 suspicious ballot boxes out of a total of 300
# Processing Elche/Elx...
#     dist_code section_code table_code  bad_counts
# 156        05          016          B           4
# 206        07          001          B           4
# 183        06          009          B           4
# 85         03          017          B           4
# 233        07          018          A           4
# 244 suspicious ballot boxes out of a total of 348
# Processing Vitoria-Gasteiz...
#     dist_code section_code table_code  bad_counts
# 24         01          024          U           5
# 52         02          009          B           5
# 113        03          013          U           4
# 192        05          013          A           4
# 61         02          017          A           4
# 226 suspicious ballot boxes out of a total of 305

# %%
dist_code = '11'
section_code = '022'
table_code = 'A'
summary = eldata.loc[(eldata['section_code'] == section_code) \
                      & (eldata['dist_code'] == dist_code) \
                      & (eldata['table_code'] == table_code), :]\
    .sort_values('votes', ascending = False)
display(summary)
# Out:
#        dist_code party_code                                     party_name  \
# 389191        11     123076                                PARTIDO POPULAR
# 389192        11     123186              PARTIDO SOCIALISTA OBRERO ESPAÑOL
# 389181        11     122515                     IZQUIERDA UNIDA-LOS VERDES
# 389197        11     123780                    UNION PROGRESO Y DEMOCRACIA
# 389175        11     121182                           CIUDADANOS EN BLANCO
# 389198        11     123960                                 FAMILIA Y VIDA
# 389185        11     122895     PARTIDO COMUNISTA DE LOS PUEBLOS DE ESPAÑA
# 389177        11     121446                                   ECOLO VERDES
# 389182        11     122620                                     LA FALANGE
# 389193        11     123438                         POR UN MUNDO MAS JUSTO
# 389190        11     123068                                 PARTIDO PIRATA
# 389174        11     120694                           ALTERNATIVA ESPAÑOLA
# 389184        11     122891                             PARTIDO CASTELLANO
# 389187        11     122922             PARTIDO DE LOS MAYORES Y AUTONOMOS
# 389188        11     122987                              PARTIDO HUMANISTA
# 389189        11     123058    PARTIDO OBRERO SOCIALISTA INTERNACIONALISTA
# 389183        11     122876  PARTIDO ANTITAURINO CONTRA EL MALTRATO ANIMAL
# 389180        11     121716                       FORO CENTRO Y DEMOCRACIA
# 389179        11     121699               FALANGE ESPAÑOLA DE LAS J.O.N.S.
# 389178        11     121696                              FALANGE AUTENTICA
# 389194        11     123504                                   REGENERACION
# 389195        11     123652                UNIFICACION COMUNISTA DE ESPAÑA
# 389196        11     123771                              UNION POR LEGANES
# 389176        11     121193            CIUDADANOS-PARTIDO DE LA CIUDADANIA
# 389186        11     122911                 PARTIDO DE FUMADORES ESPAÑOLES
#
#        prov_code section_code table_code town_code  votes
# 389191        28          022          A       079    158
# 389192        28          022          A       079     99
# 389181        28          022          A       079     56
# 389197        28          022          A       079     37
# 389175        28          022          A       079      4
# 389198        28          022          A       079      2
# 389185        28          022          A       079      2
# 389177        28          022          A       079      2
# 389182        28          022          A       079      2
# 389193        28          022          A       079      1
# 389190        28          022          A       079      1
# 389174        28          022          A       079      1
# 389184        28          022          A       079      1
# 389187        28          022          A       079      0
# 389188        28          022          A       079      0
# 389189        28          022          A       079      0
# 389183        28          022          A       079      0
# 389180        28          022          A       079      0
# 389179        28          022          A       079      0
# 389178        28          022          A       079      0
# 389194        28          022          A       079      0
# 389195        28          022          A       079      0
# 389196        28          022          A       079      0
# 389176        28          022          A       079      0
# 389186        28          022          A       079      0
